# %%
from fastai import *
from fastai.vision import *
import torch
import os
import shutil                             
import random
import pandas as pd
# !pip install ipdb
# import ipdb
import torch.nn as nn
import torchvision
from torchvision import models
import torchvision.transforms as transforms 
from torch.utils.data.sampler import SubsetRandomSampler
from PIL import Image
import torch.nn.functional as F

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
data_path = "/content/gdrive/Shared drives/Junyiwu1688/Database/koniq10k_1024x768/1024x768"
csv_path = "/content/gdrive/Shared drives/Junyiwu1688/Database/koniq10k_scores_and_distributions/koniq10k_scores_and_distributions.csv"
path = "/content/gdrive/Shared drives/Junyiwu1688/Database/"
# os.chdir(path)

# %%
# !ls gdrive/My Drive/
# Out:
# ls: cannot access 'gdrive/My': No such file or directory
# ls: cannot access 'Drive/': No such file or directory

# %%
# !cd gdrive

# %%
# !ls
# Out:
# gdrive	sample_data
